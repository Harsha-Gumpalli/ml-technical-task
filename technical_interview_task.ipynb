# %% [markdown]
# AI senior developer testing

# %% [markdown]
# For:
# - define the task (ask hamza o create a google account for the task)
# - make it in form (Sami)
# - set up from where they can load the data from (400 images per plant type and give them 3 plant types cucumber basil and elerholm's plants) (Sami)
# - give them cmap images
# - explain how do we build cmap images (Sami)
# - set up the PC (Ahmed)

# %% [markdown]
# Instructions ⁉
# -
# - developing a pipeline to detect stress patterns in cmap images
# data : cmap images only

# %% [markdown]
# technical interview phases -
#
# 1. brainstorm, think, sketch a solution and present to audiance (no internet acess, the evaluators can ask question, and mention potential problems they will face
# 2.  implementing the solution (access to everything )
# 3. Presenting the solution, questions regarding hwo close the final solution si from what they presented in the beginning.
